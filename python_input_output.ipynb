# %%
'''
Question 1:
Description:
Write a program to print the welcome note for the aliens, who are arriving to earth for the first
time.
Input Format:
Get the welcome note message from the user as string
Output Format:
print the message
Constraints:
NA
Example:
Sample Input:
Welcome to Earth, Aliens!!!
Sample Output:
Welcome to Earth, Aliens!!!
'''a = input()
print(a)
# Out:
# Get the welcome note message from the user as string
# Get the welcome note message from the user as string

# %%
'''
Question 2:
Description:
Stadium's Name:
MECON LIMITED was a public sector undertaking firm under the ministry of steel where
Dhoni's father had worked for. It was the stadium where MS Dhoni grew up playing.
The Chairman of MECON decided to renovate and improvise the facilities in the stadium and
to place a NEON display board at the entry of the stadium that carried the Stadium's name
as "MECON Stadium".
Write a program to display the Stadium name in different lines.
Input Format:
There is no input
Output Format:
Print the name "MECON Stadium" in different lines.
Constraints:
NA
Example:
SAMPLE OUTPUT:
MECON
Stadium
'''
a = ("MEXCON")
b = ("stadium")
print(a)
print(b)
# Out:
# MEXCON
# stadium

# %%
'''
Question 3:
Description:
Interschool Trophy
It was in the 1997-98 season that Ranchi saw the rise of the Captain Cool in the interschool
trophy between DAV Jawahar Vidhya Mandir and Kendriya School. It was in that match
Dhoni convinced Banerjee to be the opener and justified it with a double century.
Write a program to display the details of the match with Team name, Scores of the team and
Overs played.
Input and Output Format:
● Refer sample input and output for formatting specifications.
Constraints:
NA
Example:
Sample Input:
DAV Jawahar Vidhya Mandir
150
20
Kendriya School
110
18
Sample Output:
Match Details:
Team 1:
Name: DAV Jawahar Vidhya Mandir
Score: 150
Overs played: 20
Team 2:
Name: Kendriya School
Score: 110
Overs played: 18
'''# Team 1 input
a = input()
b = int(input())
c = int(input())

# Team 2 input
d = input()
e = int(input())
f = int(input())

# Output
print("Match Details:")
print("Team 1:")
print("Name:", a)
print("Score:", b)
print("Overs played:", c)

print("Team 2:")
print("Name:", d)
print("Score:", e)
print("Overs played:", f)
# Out:
# jpc
# 200
# 20
# dcf
# 170
# 20
# Match Details:
# Team 1:
# Name: jpc
# Score: 200
# Overs played: 20
# Team 2:
# Name: dcf
# Score: 170
# Overs played: 20

# %%
'''
Question 4:
Description:
FAVORITE GAME!!
Keshab Ranjan Banerjee, a senior sports teacher at Dhoni's Jawahar Vidhya Mandhir
School, spotted Dhoni when he was goal keeping for a football match.
He got impressed by Dhoni's saves and thought of trying him out behind the stumps for the
school's cricket team. In his first meet with Dhoni, Banerjee asked him his name and the
game that Dhoni loves to play. Write a program to display Dhoni's reply.
Input and Output Format:
● Refer the sample input and output for formatting specifications.
Constraints:
NA
Example:
Sample Input:
MS Dhoni
Football
Sample Output:
My name is MS Dhoni and I love to play Football
'''
a = ("MS Dhoni")
b = ("Football")
print ("My name is",a,"and I love to play",b)
# Out:
# My name is MS Dhoni and I love to play Football

# %%
'''
Question 5:
Description:
Dhoni's Age!!!
MS Dhoni aged X years, is a Cancerian, born with very strong Mars in his birth chart.
Notably, Mars is the rulling planet for sports. Write a program to get the age of Dhoni as an
integer and display the same.
Input Format:
● Input is an integer that corresponds to the age of Dhoni.
Output Format:
● Display the age.
● Refer sample Input and Output for formatting specifications.
Constraints:
NA
Example:
Sample Input and Output:
35
Age of Dhoni is 35
'''
age = int(input())
print("Age of Dhoni is",age)
# Out:
# 35
# Age of Dhoni is 35

# %%
'''
Question 6:
Description:
Write a program to print a character
INPUT & OUTPUT FORMAT:
● Input consists of 1 character. Output consists of 1 character.
Constraints:
NA
Example:
Sample Input:
A
Sample Output:
A
'''ch =(input())
print(ch)
# Out:
# A
# A

# %%
'''
Question 7:
You are working as the bowling assist during the practice session before match. All the
bowlers are asking the speed of the ball. So, you need to get the ball speed and print the ball
speed with only 2 decimal value.
Input Format:
Input value consists of double value
Output Format:
● Output value consists of double value with 2 decimal value.
Constraints:
NA
Example:
Sample Input:
141.236
Sample Output:
141.24


'''
a = 141.236
print("%.2f"%a)
# Out:
# 141.24

# %%
'''
Description:
Ravi and Varma went to a textile shop for festival purchase. Ravi took few T-shirts and went
for billing. Varma wants discount on the purchased items. The biller shows computer
keyboard and asks to press an alpha numeric key and that key’s ASCII value will be the
discounted amount on the purchase. Help Varma to know his discounted amount.
Input Format:
● A single alphanumeric character (a letter or digit) entered by the user.
Output Format:
● The ASCII value of the entered character.
Constraints:
NA
Example:
Sample Input:
A
Sample Output:
65
'''
ch = input()
print(ord(ch))
# Out:
# g
# 103

# %%
'''
Question 9:
Description:
ASCII - American Standard Code for Information Interchange.
Write a program to get a number(ASCII) as input and print its equivalent character.
You can display a character if you know ASCII code of that character.
Input and Output Format
Input:
● A single integer representing an ASCII value.
Output:
● The corresponding character for the given ASCII value.
Constraints:
NA
Example:
Sample Input:
103

Sample Output:
g
'''
n = int(input())
print(chr(n))
# Out:
# 65
# A

# %%
'''
Question 10:
Description:
In Beirut, there was a very huge explosion. Millions and millions worth buildings and property
were destroyed. Many people lost their lives while some of them were injured and few were
safe. A news reporter arrives at the spot to take the current survey regarding the situation of
the people alive, dead and injured. He wanted to publish it in the newspaper and reach out
to other countries asking to help the affected people. Can you please help him in this noble
cause by writing a program to generate the newspaper report?

INPUT & OUTPUT FORMAT:
● Input consists of three integers corresponding to the number of people dead, injured
and those who are still alive and safe.
● Refer sample input and output for formatting specifications.

Constraints:
NA

Example:
Sample Input:
2000
3000
10000

Sample Output:
1)Dead:2000
2)Injured:3000
3)Safe:10000
Please help the people who are suffering!!!
'''
a = int(input())
b = int(input())
c = int(input())
print("1)Dead:",a)
print("2)Injured:",b)
print("3)Safe:",c)
print("Please help the people who are suffering!!!")
# Out:
# 1000
# 2000
# 5000
# 1)Dead: 1000
# 2)Injured: 2000
# 3)Safe: 5000
# Please help the people who are suffering!!!
